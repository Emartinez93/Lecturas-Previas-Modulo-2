# %% [markdown]
# # Lectura Iphone

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import pandas_datareader.data as web
import pandas_datareader as pdr
from datetime import datetime
from pandas import Series,DataFrame
from datetime import date
from datetime import timedelta
import yfinance as yf

# %%
my_list = ["AAPL"]

# %%
end = datetime.now()-timedelta(days=3300)

start = datetime(end.year-1,end.month,end.day)

# %%
for stock in my_list:
    df_yahoo = yf.download(my_list,start= start,end=end,progress=False)

# %%
df_yahoo['Adj Close'].plot(legend=True,figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Lectura AVON

# %%
my_list2 = ["NTCO"] #NTCO

# %%
end = datetime.now()-timedelta(days=600)

start = datetime(end.year-1,end.month,end.day)

# %%
for stock in my_list2:
    df_yahoo1 = yf.download(my_list2,start= start,end=end,progress=False)

# %%
df_yahoo1['Adj Close'].plot(legend=True,figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Lectura IBM

# %%
my_list3 = ["IBM"]

# %%
end = datetime.now()-timedelta(days=2900)

start = datetime(end.year-1,end.month,end.day)

# %%
for stock in my_list3:
    df_yahoo2 = yf.download(my_list3,start= start,end=end,progress=False)

# %%
df_yahoo2['Adj Close'].plot(legend=True,figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>
